# %% [markdown]
# # Projeto Dashboard Treino e Dieta - Gabriel Ferreira

# %% [markdown]
# ## 1. Processso de ETL

# %%
# Instalando pacotes necessários
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Carregando os dados
df = pd.read_csv('workouts.csv')

# %%
# Shape
df.shape
# Out:
# (9480, 14)

# %%
# Amostra dos dados
df.head(10)
# Out:
#                 title         start_time           end_time  \
# 0  Evening workout 🏋️  7 Jan 2026, 19:48  7 Jan 2026, 20:14
# 1  Evening workout 🏋️  7 Jan 2026, 19:48  7 Jan 2026, 20:14
# 2  Evening workout 🏋️  7 Jan 2026, 19:48  7 Jan 2026, 20:14
# 3  Evening workout 🏋️  7 Jan 2026, 19:48  7 Jan 2026, 20:14
# 4  Evening workout 🏋️  7 Jan 2026, 19:48  7 Jan 2026, 20:14
# 5  Evening workout 🏋️  7 Jan 2026, 19:48  7 Jan 2026, 20:14
# 6               Lower  6 Jan 2026, 19:46  6 Jan 2026, 21:24
# 7               Lower  6 Jan 2026, 19:46  6 Jan 2026, 21:24
# 8               Lower  6 Jan 2026, 19:46  6 Jan 2026, 21:24
# 9               Lower  6 Jan 2026, 19:46  6 Jan 2026, 21:24
#
#                 description                            exercise_title  \
# 0  Lower back,  pantu e abs  Back Extension (Weighted Hyperextension)
# 1  Lower back,  pantu e abs  Back Extension (Weighted Hyperextension)
# 2  Lower back,  pantu e abs       Unilateral Calf Extension (Machine)
# 3  Lower back,  pantu e abs       Unilateral Calf Extension (Machine)
# 4  Lower back,  pantu e abs                     Crunch Hammer Machine
# 5  Lower back,  pantu e abs                     Crunch Hammer Machine
# 6                       NaN                   Hip Adduction (Machine)
# 7                       NaN                   Hip Adduction (Machine)
# 8                       NaN                   Hip Adduction (Machine)
# 9                       NaN                     Straight Leg Deadlift
#
#    superset_id exercise_notes  set_index set_type  weight_kg  reps  \
# 0          NaN            NaN          0   normal      40.00   8.0
# 1          NaN            NaN          1   normal      42.50   7.0
# 2          NaN            NaN          0   normal      52.50   8.0
# 3          NaN            NaN          1  failure      52.50   8.0
# 4          NaN            NaN          0   normal      57.50   7.0
# 5          NaN            NaN          1  failure      57.50   7.0
# 6          NaN            NaN          0   normal      90.00   5.0
# 7          NaN            NaN          1  failure      90.00   5.0
# 8          NaN            NaN          2  failure      86.25   6.0
# 9          NaN            NaN          0   normal     100.00   7.0
#
#    distance_km  duration_seconds  rpe
# 0          NaN               NaN  NaN
# 1          NaN               NaN  NaN
# 2          NaN               NaN  NaN
# 3          NaN               NaN  NaN
# 4          NaN               NaN  NaN
# 5          NaN               NaN  NaN
# 6          NaN               NaN  NaN
# 7          NaN               NaN  NaN
# 8          NaN               NaN  NaN
# 9          NaN               NaN  NaN

# %%
# Tipo de dados
df.dtypes
# Out:
# title                object
# start_time           object
# end_time             object
# description          object
# exercise_title       object
# superset_id         float64
# exercise_notes       object
# set_index             int64
# set_type             object
# weight_kg           float64
# reps                float64
# distance_km         float64
# duration_seconds    float64
# rpe                 float64
# dtype: object

# %% [markdown]
# Observa-se que o start_time e end_time estão como object e deveriam ser datas.

# %%
# Colunas
df.columns
# Out:
# Index(['title', 'start_time', 'end_time', 'description', 'exercise_title',
#        'superset_id', 'exercise_notes', 'set_index', 'set_type', 'weight_kg',
#        'reps', 'distance_km', 'duration_seconds', 'rpe'],
#       dtype='object')

# %%
# Criação do dicionário de dados com a descrição de cada variável
df_dict = {
    "title": "Nome do treino (Push, Pull, Legs, Push 1, Pull 1, Treino A, etc.",
    "start_time": "Data e horárrio do início do treino.",
    "end_time": "Data e horárrio do final do treino.",
    "description": "Comentários adicionados ao final do treino.",
    "exercise_title": "Nome do exercício realizado.",
    "superset_id": "Index para identificar supersets.",
    "exercise_notes": "Anotacoes realizadas durante a realizacao do exercicio.",
    "set_index": "Numero da serie realizada",
    "set_type": "Tipo de serie (Normal, Failure, Warmup).",
    "weight_kg": "Carga levantado na serie.",
    "reps": "Numero de repeticoes realizadas na serie.",
    "distance_km": "Distancia em kilometros realizadas no exercicio cardiovascular",
    "duration_segundos": "Duracao em segundos do exercicio cardiovascular ou exercicio que e controlado por tempo.",
    "rpe": "Rating of Perceived Exertion = Escala de Esforço Percebido. Escala subjetiva para avaliar a intensidade do esforço no treino."
}

# %% [markdown]
# Não tem a necessidade de se obter o horario incial e final do treino juntamente com a data, portanto precisamos quebrar em uma coluna com a data do treino (data_treino) e também o tempo de treino (horario do inicio_treino e final_treino).

# %% [markdown]
# ### Análise Exploratória

# %%
# Verificando novamente tipo de dados
df.dtypes
# Out:
# title                object
# start_time           object
# end_time             object
# description          object
# exercise_title       object
# superset_id         float64
# exercise_notes       object
# set_index             int64
# set_type             object
# weight_kg           float64
# reps                float64
# distance_km         float64
# duration_seconds    float64
# rpe                 float64
# dtype: object

# %%
# Resumo estatístico (variáveis numéricas)
df.describe()
# Out:
#        superset_id    set_index   weight_kg         reps  distance_km  \
# count          0.0  9480.000000  8776.00000  9151.000000          1.0
# mean           NaN     1.140506    52.49430     9.469238          5.0
# std            NaN     1.180906    37.69122     2.975475          NaN
# min            NaN     0.000000     2.00000     4.000000          5.0
# 25%            NaN     0.000000    21.25000     8.000000          5.0
# 50%            NaN     1.000000    47.50000     9.000000          5.0
# 75%            NaN     2.000000    75.00000    11.000000          5.0
# max            NaN     9.000000   285.00000   111.000000          5.0
#
#        duration_seconds  rpe
# count        329.000000  0.0
# mean        1039.659574  NaN
# std          247.233633  NaN
# min            0.000000  NaN
# 25%          900.000000  NaN
# 50%         1200.000000  NaN
# 75%         1200.000000  NaN
# max         1800.000000  NaN

# %%
# Visualizando o total de linhas por coluna
df.count()
# Out:
# title               9480
# start_time          9480
# end_time            9480
# description         4278
# exercise_title      9480
# superset_id            0
# exercise_notes      1068
# set_index           9480
# set_type            9480
# weight_kg           8776
# reps                9151
# distance_km            1
# duration_seconds     329
# rpe                    0
# dtype: int64

# %%
# Extraindo o total de valores ausentes por coluna
valores_ausentes = df.isnull().sum().sort_values(ascending = False)
print(valores_ausentes)
# Out:
# superset_id         9480
# rpe                 9480
# distance_km         9479
# duration_seconds    9151
# exercise_notes      8412
# description         5202
# weight_kg            704
# reps                 329
# title                  0
# start_time             0
# exercise_title         0
# end_time               0
# set_type               0
# set_index              0
# dtype: int64

# %% [markdown]
# superset_id == nunca utilizo então faz sentido estar com todos valores ausentes
# rpe == mesmo do superset_id
# distance_km == somente se colocar na esteira.. geralmente nao coloco pois faço por tempo
# duration_seconds == duracao do cardio..só vai estar presente nos exercicios de cardio
# exercise_notes == comentarios dos exercicios, nem sempre é necessário ter comentario
# description == descrição do treinamento, se coloca ao finalizar o treino, nem sempre tbm colocamos
#
#
# weight_kg = alguns exercicios nao tem carga, como exercicios com peso corporal e cardio, mas irei analisar
# reps = analisemos

# %%
# Valores ausentes coluna weight_kg
# Filtrando linhas onde 'wight_kg' é NaN e não são cardio
exercicios_excluidos = ['Treadmill', 'Stair Machine (Floors)', 'Stair Machine (Steps)', 'Stair Machine','Spinning', 'Walking', 'Air Bike']

linhas_ausentes_carga = df[
    df['weight_kg'].isna() &
    ~df['exercise_title'].isin(exercicios_excluidos)
]

linhas_ausentes_carga
# Out:
#                            title          start_time            end_time  \
# 1678                     Upper I  26 May 2025, 19:46  26 May 2025, 21:23
# 1679                     Upper I  26 May 2025, 19:46  26 May 2025, 21:23
# 1737                     Upper I  19 May 2025, 19:54  19 May 2025, 21:43
# 3092             Push 2 e Pull 2  28 Dec 2024, 09:18  28 Dec 2024, 10:59
# 3093             Push 2 e Pull 2  28 Dec 2024, 09:18  28 Dec 2024, 10:59
# ...                          ...                 ...                 ...
# 9349  Treino A - Costas + Biceps  27 Nov 2023, 17:19  27 Nov 2023, 18:18
# 9456  Treino A - Costas + Biceps  21 Nov 2023, 17:54  21 Nov 2023, 18:48
# 9457  Treino A - Costas + Biceps  21 Nov 2023, 17:54  21 Nov 2023, 18:48
# 9458  Treino A - Costas + Biceps  21 Nov 2023, 17:54  21 Nov 2023, 18:48
# 9459  Treino A - Costas + Biceps  21 Nov 2023, 17:54  21 Nov 2023, 18:48
#
#      description                   exercise_title  superset_id exercise_notes  \
# 1678         NaN             Chest Dip (Assisted)          NaN            NaN
# 1679         NaN             Chest Dip (Assisted)          NaN            NaN
# 1737         NaN             Chest Dip (Assisted)          NaN            NaN
# 3092      Pull 2           Romanian Chair Sit Ups          NaN            NaN
# 3093      Pull 2           Romanian Chair Sit Ups          NaN            NaN
# ...          ...                              ...          ...            ...
# 9349         NaN  Back Extension (Hyperextension)          NaN            NaN
# 9456         NaN  Back Extension (Hyperextension)          NaN            NaN
# 9457         NaN  Back Extension (Hyperextension)          NaN            NaN
# 9458         NaN  Back Extension (Hyperextension)          NaN            NaN
# 9459         NaN  Back Extension (Hyperextension)          NaN            NaN
#
#       set_index set_type  weight_kg  reps  distance_km  duration_seconds  rpe
# 1678          0   normal        NaN   8.0          NaN               NaN  NaN
# 1679          1  failure        NaN   8.0          NaN               NaN  NaN
# 1737          1  failure        NaN   7.0          NaN               NaN  NaN
# 3092          0   normal        NaN   9.0          NaN               NaN  NaN
# 3093          1   normal        NaN   7.0          NaN               NaN  NaN
# ...         ...      ...        ...   ...          ...               ...  ...
# 9349          3   normal        NaN  10.0          NaN               NaN  NaN
# 9456          0   normal        NaN  10.0          NaN               NaN  NaN
# 9457          1   normal        NaN  10.0          NaN               NaN  NaN
# 9458          2   normal        NaN  10.0          NaN               NaN  NaN
# 9459          3   normal        NaN  10.0          NaN               NaN  NaN
#
# [376 rows x 14 columns]

# %%
# Visualizando onde temos valores ausentes
linhas_ausentes_carga = df[
    df['weight_kg'].isna() &
    ~df['exercise_title'].isin(exercicios_excluidos)
]

linhas_ausentes_carga['exercise_title'].value_counts()
# Out:
# exercise_title
# Back Extension (Hyperextension)    201
# Pull Up                             86
# Knee Raise Parallel Bars            53
# Leg Raise Parallel Bars              8
# Bench Dip                            7
# Decline Crunch                       4
# Chin Up                              4
# Chest Dip (Assisted)                 3
# Romanian Chair Sit Ups               3
# Decline Crunch (Weighted)            2
# Squat (Smith Machine)                1
# Squat (Bodyweight)                   1
# Push Up                              1
# Bicep Curl (Machine)                 1
# Plank                                1
# Name: count, dtype: int64

# %% [markdown]
# Back Extension (Hyperextension), Pull Up, Knee Raise Parallel Bars, Leg Raise Parallel Bars, Bench Dip, Decline Crunch, Chin Up, Chest Dip (Assisted),
# Romanian Chair Sit Ups, Decline Crunch (Weighted), Squat (Bodyweight), Push Up  e Plank fazem sentido valores ausentes pois são exercicios com peso do corpo apenas, mas Bicep Curl (Machine) não e provavelmente o Squat (Smith Machine) foi um aquecimento sem carga, mas vamos analisar

# %%
# Filtrando esses dois exercicios com valores nulos em weight_kg
exercicios_interesse = [
    'Squat (Smith Machine)',
    'Bicep Curl (Machine)'
]

df[
    df['weight_kg'].isna() &
    df['exercise_title'].isin(exercicios_interesse)
]
# Out:
#                                     title          start_time  \
# 5208                       Perna Completo  31 Jul 2024, 07:42
# 6582  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
#
#                 end_time description         exercise_title  superset_id  \
# 5208  31 Jul 2024, 09:01         NaN  Squat (Smith Machine)          NaN
# 6582  14 May 2024, 12:36         NaN   Bicep Curl (Machine)          NaN
#
#      exercise_notes  set_index set_type  weight_kg  reps  distance_km  \
# 5208            NaN          0   warmup        NaN  30.0          NaN
# 6582            NaN          2  failure        NaN   9.0          NaN
#
#       duration_seconds  rpe
# 5208               NaN  NaN
# 6582               NaN  NaN

# %% [markdown]
# Confirmamos Smith Machine como aquecimento, mas provavelmente temos um erro no exercicio de biceps, pois é uma série até a falha e o set_index é 2, o que siginfica que é a terceira série desse exercicio

# %%
# Analisando exatamente esse exercicio desse dia
df[
    (df['title'] == 'Costas + Biceps + Lombar - Treino 2') &
    (df['exercise_title'] == 'Bicep Curl (Machine)') &
    (df['start_time'].str.contains('14 May 2024'))
]
# Out:
#                                     title          start_time  \
# 6580  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
# 6581  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
# 6582  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
#
#                 end_time description        exercise_title  superset_id  \
# 6580  14 May 2024, 12:36         NaN  Bicep Curl (Machine)          NaN
# 6581  14 May 2024, 12:36         NaN  Bicep Curl (Machine)          NaN
# 6582  14 May 2024, 12:36         NaN  Bicep Curl (Machine)          NaN
#
#      exercise_notes  set_index set_type  weight_kg  reps  distance_km  \
# 6580            NaN          0   normal       54.0  12.0          NaN
# 6581            NaN          1  failure       54.0  10.0          NaN
# 6582            NaN          2  failure        NaN   9.0          NaN
#
#       duration_seconds  rpe
# 6580               NaN  NaN
# 6581               NaN  NaN
# 6582               NaN  NaN

# %% [markdown]
# Após analise, comprovamos que de fato houve um erro na imputação manual, refletindo na ausência desse valor, que é 54.0 kg

# %%
# Imputando o valor correto nessa série
df.loc[6582, 'weight_kg'] = 54.0

# %%
# Revalidando a serie correta
df[
    (df['title'] == 'Costas + Biceps + Lombar - Treino 2') &
    (df['exercise_title'] == 'Bicep Curl (Machine)') &
    (df['start_time'].str.contains('14 May 2024'))
]
# Out:
#                                     title          start_time  \
# 6580  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
# 6581  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
# 6582  Costas + Biceps + Lombar - Treino 2  14 May 2024, 11:11
#
#                 end_time description        exercise_title  superset_id  \
# 6580  14 May 2024, 12:36         NaN  Bicep Curl (Machine)          NaN
# 6581  14 May 2024, 12:36         NaN  Bicep Curl (Machine)          NaN
# 6582  14 May 2024, 12:36         NaN  Bicep Curl (Machine)          NaN
#
#      exercise_notes  set_index set_type  weight_kg  reps  distance_km  \
# 6580            NaN          0   normal       54.0  12.0          NaN
# 6581            NaN          1  failure       54.0  10.0          NaN
# 6582            NaN          2  failure       54.0   9.0          NaN
#
#       duration_seconds  rpe
# 6580               NaN  NaN
# 6581               NaN  NaN
# 6582               NaN  NaN

# %%
# Valores ausentes coluna REPS
# Filtrando linhas onde 'reps' é NaN e não são cardio
exercicios_excluidos = ['Treadmill', 'Stair Machine (Floors)', 'Stair Machine (Steps)', 'Stair Machine','Spinning', 'Walking', 'Air Bike']

linhas_ausentes_repeticoes = df[
    df['reps'].isna() &
    ~df['exercise_title'].isin(exercicios_excluidos)
]

linhas_ausentes_repeticoes
# Out:
#                                        title          start_time  \
# 7960  (S1 ) Peito + Triceps + Abs - Treino 1  26 Feb 2024, 10:54
#
#                 end_time description exercise_title  superset_id  \
# 7960  26 Feb 2024, 11:53    Treino 6          Plank          NaN
#
#      exercise_notes  set_index set_type  weight_kg  reps  distance_km  \
# 7960            NaN          0   normal        NaN   NaN          NaN
#
#       duration_seconds  rpe
# 7960              48.0  NaN

# %% [markdown]
# OK faz sentido cardio sem valores em repeticoes, vamos analisar o abdominals

# %%
# Remover espaços em branco e ajustar capitalização na coluna 'grupo_muscular'
df_hevy_dados['grupo_muscular'] = df_hevy_dados['grupo_muscular'].str.strip().str.lower()

# Filtrar linhas onde 'repeticoes' é NaN e 'grupo_muscular' é 'abdominals'
linhas_abdominals = df_hevy_dados[(df_hevy_dados['repeticoes'].isna()) & (df_hevy_dados['grupo_muscular'] == 'abdominals')]

# Exibindo a(s) linha(s) filtrada(s) com cabeçalhos
print(linhas_abdominals.to_string(index=False))

# %% [markdown]
# OK o exercicio plank (prancha) não ter repetições

# %% [markdown]
# ### Detecção de Outliers

# %% [markdown]
# Somente temos a necessidade de detectar outliers nas colunas carga_kg, repeticoes e 1RM, as demais são variáveis categóricas ou indices.

# %%
# Função para detectar outliers usando o método IQR
def detectar_outliers(df, coluna):
    Q1 = df[coluna].quantile(0.25)
    Q3 = df[coluna].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    
    outliers = df[(df[coluna] < limite_inferior) | (df[coluna] > limite_superior)]
    return outliers

# %%
# Detectando e exibindo o total de outliers por coluna
colunas = ['carga_kg', 'repeticoes', '1RM']
for coluna in colunas:
    outliers = detectar_outliers(df_hevy_dados, coluna)
    print(f"Total de outliers em '{coluna}': {len(outliers)}")

# %%
# Detectar e exibir outliers para a coluna 'carga_kg'
outliers_carga_kg = detectar_outliers(df_hevy_dados, 'carga_kg')

if not outliers_carga_kg.empty:
    print("Outliers em 'carga_kg (43) ':")
    print(outliers_carga_kg[['exercicio', 'data_treino', 'carga_kg', 'repeticoes', '1RM']])

# %% [markdown]
# Otulers em carga_kg -- OK Leg press é um exercicio que de fato é possivel levantar muito peso (absoluto) relacionado aos demais exercicios

# %%
# Detectar e exibir outliers para a coluna '1RM'
outliers_1RM = detectar_outliers(df_hevy_dados, '1RM')

if not outliers_1RM.empty:
    print("Outliers em '1RM (44)':")
    print(outliers_1RM[['exercicio', 'data_treino', 'carga_kg', 'repeticoes', '1RM']])

# %% [markdown]
# OK - legpress pelo mesmo motivo da carga

# %%
# Detectar e exibir outliers para a coluna 'repeticoes'
outliers_repeticoes = detectar_outliers(df_hevy_dados, 'repeticoes')

if not outliers_repeticoes.empty:
    print("Outliers em 'repeticoes (209) ':")
    print(outliers_repeticoes[['exercicio','carga_kg', 'repeticoes', '1RM']])

# %% [markdown]
# Muitos registros.. vamos montar um plot

# %%
# Gráfico
dados_repeticoes = df_hevy_dados['repeticoes'].dropna()
plt.figure(figsize=(8, 6))
sns.boxplot(y=dados_repeticoes)
plt.title("Boxplot Repetições com Outliers")
plt.ylabel("Repetições")
plt.show()

# %% [markdown]
# Vemos um registro com mais de 100 repeticoes e alguns detectados como outliers entre 25 e 35.. vamos analisar os 50 primeiros.

# %%
top_50_outliers_repeticoes = outliers_repeticoes.sort_values(by='repeticoes', ascending=False).head(50)
print(top_50_outliers_repeticoes[['exercicio', 'data_treino', 'carga_kg', 'repeticoes',]])

# %% [markdown]
# Temos um valor incorreto que seria 111 repetições. Os demais exercicios estão OK pois foram ou panturilha o que exige as vezes maior numero de repetições ou em semanas com carga baixa e altas repetições.
#
# Somenta a linha 4339 temos um valor incorreto que seria 111. Na realidade são 11 repetições

# %%
# Corrigir o valor na coluna 'repeticoes' para a linha 4339
df_hevy_dados.at[4339, 'repeticoes'] = 11

# %%
# Exibir a linha após a correção para confirmar a alteração
print("\nApós a correção:")
print(df_hevy_dados.loc[4339, ['exercicio', 'data_treino', 'carga_kg', 'repeticoes']])

# %%
# Grafico
dados_repeticoes = df_hevy_dados['repeticoes'].dropna()
plt.figure(figsize=(8, 6))
sns.boxplot(y=dados_repeticoes)
plt.title("Repeticoes sem Outliers")
plt.ylabel("Repetições")
plt.show()

# %% [markdown]
# ### Analise Final

# %%
df_hevy_dados.sample(50)

# %%
# Reorganizando colunas
nova_ordem_colunas = [
    'data_treino', 'tempo_treino', 'treino', 'descricao_treino',
    'exercicio', 'serie', 'tipo_serie', 'carga_kg', 'repeticoes',
    '1RM', 'grupo_muscular', 'anotacoes_exercicios', 'ciclo'
]

df_hevy_dados = df_hevy_dados[nova_ordem_colunas]

# %%
df_hevy_dados.sample(10)

# %%
# Salvar o DataFrame transformado em um novo arquivo
df_hevy_dados.to_csv('etl_dfhevy.csv', index=False)
